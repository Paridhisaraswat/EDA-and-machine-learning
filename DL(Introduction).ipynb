# %%
# Introduction to Deep learning ::::
# Work Based on Human Nervous System -----> works on Neuron ----> Inspired ------>
# Artificial Neural Network


# when benificial
# ML  ----> when we have less complex data
# DL ----> when we have more complex data

# %%
# .(x11)
            # .(x21)

# .(x12)                   .(x31)    ----->Output(y)
              # .(x22)

# .(x13)

# %%
# (x11) ---> (x21) ---> (x31) --- y   (Forward Propagation)
# y ---> x31 ----> x21 ----> x11 (Backward propagation)

# %%
# chain Rule

# dy/dx11 = (dy/dx31 * dx31/dx21 * dx21/dx11) + (dy/dx31 * dx31/dx22 * dx22/dx11)

# dy/dx12 = (dy/dx31 * dx31/dx21 * dx21/dx12) + (dy/dx31 * dx31/dx22 * dx22/dx12)

# dy/dx13 = (dy/dx31 * dx31/dx21 * dx21/dx13) + (dy/dx31 * dx31/dx22 * dx22/dx13)

# %%
# workflow of Ml
# Data Ingestion -----> Data Preprocessing ----> Select ML Model ----> Train the model --->
# Prediction ----> Calculation Accuracy

# %%
# Workflow of Dl ::::
# Data Ingestion -----> Data Cleaning and Preprocessing ---->

# create a Model Sequential
# input_layer(input_columns , Neurons , Activation_function)
# hidden_layer (Neuron , Activation_function)
# output_layer(Neuron based on the target column , Activation_function)

# Model.compile(loss_fn (diff b/w actual - predicted value), optimizer(minimize loss_fn) , Metrics)

# Model.training

# Model.Prediction

# Model Total Loss and Total Accuracy

# %%
# Loss Function ---->(difference between actual and predicted points) it is the distance between Actual and Predicted point

# (1). when we have 2 sub-categories in target column , then we will use
# 'Binary_Cross_entropy' as a loss function

# (2). when we have more than 2 sub-categories in target column , then we will use
# 'Sparse_categorical_corss_entropy'

# (3). when we have Numerical Target column then we use 'MSE , MAE' as loss function

# %%
# Optimization technique in Ml::::

# (1). Gradient Descent -----> Entire Data respect ----> y = m_new * X + b_new

# (2). Stocastic G.D. ----> in this we will select a random row and then we calculate
# y = m_new * X + b_new

# (3). MINI Batch G.D. ----> in this we will select our batch
# if we have 100 rows then
# A batch - 25
# b Batch - 25
# C batch - 25
# D batch - 25

# we will select a rondom Batch using numpy random module .
# let suppose if we have B - Batch , then in this batch we have total 25 rows (x) and
# thier columns are m or weights . so using this data , it will reduce the loss function
# and find the best y = m_new * X + b_new
