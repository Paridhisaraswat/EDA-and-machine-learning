# %%
# Column Transformer
# is used to apply different preprocessing techniques to different columns of a dataset simultaneously

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(
    df.drop(columns =['has_covid']),
    df['has_covid'],
    test_size = 0.2,
    random_state= 1)

# %%
x_train
# Out:
#     age  gender  fever   cough       city
# 2    42    Male  101.0    Mild      Delhi
# 73   34    Male   98.0  Strong    Kolkata
# 97   20  Female  101.0    Mild  Bangalore
# 62   56  Female  104.0  Strong  Bangalore
# 19   42  Female    NaN  Strong  Bangalore
# ..  ...     ...    ...     ...        ...
# 75    5    Male  102.0    Mild    Kolkata
# 9    64  Female  101.0    Mild      Delhi
# 72   83  Female  101.0    Mild    Kolkata
# 12   25  Female   99.0  Strong    Kolkata
# 37   55    Male  100.0    Mild    Kolkata
#
# [80 rows x 5 columns]

# %% [markdown]
# #Manually type output

# %%
# adding simple imputer to fever column

si = SimpleImputer(strategy ='mean')
x_train_fever = si.fit_transform(x_train[['fever']])


# also the test data
x_test_fever = si.fit_transform(x_test[['fever']])

x_train_fever.shape
# Out:
# (80, 1)

# %%
# ordinal Encoding ----> cough

oe = OrdinalEncoder(categories = [['Mild','Strong']])
x_train_cough = oe.fit_transform(x_train[['cough']])

# also the test data

x_test_cough = oe.fit_transform(x_test[['cough']])

x_train_cough.shape
# Out:
# (80, 1)

# %%
# onehotEncoder ---> Gender , city

ohe = OneHotEncoder(drop = 'first', sparse_output = False)
x_train_gender_city = ohe.fit_transform(x_train[['gender','city']])

# also the test data
x_test_gender_city = ohe.fit_transform(x_test[['gender','city']])

x_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age

x_train_age = x_train.drop(columns = ['gender','fever','cough','city']).values


# also the test data

x_test_age = x_test.drop(columns = ['gender','fever','cough','city']).values

# %%
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transfromed = np.concatenate((x_train_age,x_train_fever,
                                     x_train_gender_city,x_train_cough),axis = 1 )

# %%
x_test_transfromed = np.concatenate((x_test_age,x_test_fever,
                                     x_test_gender_city,x_test_cough),axis = 1 )

# %%
x_train_transfromed.shape
# Out:
# (80, 7)

# %% [markdown]
# #by the help of column Transformer

# %%
from sklearn.compose import ColumnTransformer

# constant
# approach
# columns name

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']) ,           #in a 'fever' column by the help of  SI

    # we fill missing values by mean , median , mode
    ('tnf2', OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),

    # by this process we encode the data
    ('tnf3',OneHotEncoder(sparse_output = False , drop = 'first'),['gender','city'])

] , remainder='passthrough')
  #remainder = passthrough ==>
# it means rest all the columns remain same

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
transformer.fit_transform(x_test).shape
# Out:
# (20, 7)

# %%
import seaborn as sns

# %%
a = sns.load_dataset('tips')
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
a = a.drop(columns = ['size'])

# %%
a.shape
# Out:
# (244, 6)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(a.drop(columns = ['total_bill']),
                                                       a['total_bill'],test_size = 0.2,
                                                       random_state = 1)

# %%
x_train.shape
# Out:
# (195, 5)

# %%
oe = OrdinalEncoder(categories=[['Female','Male']])

x_train_sex = oe.fit_transform(x_train[['sex']])
x_test_sex = oe.fit_transform(x_test[['sex']])

# %%
x_train_sex.shape
# Out:
# (195, 1)

# %%
ohe = OneHotEncoder(drop = 'first', sparse_output = False)
x_train_dt = ohe.fit_transform(x_train[['time','day','smoker']])

# %%
x_test_dt = ohe.fit_transform(x_test[['time','day','smoker']])
x_train_dt.shape
# Out:
# (195, 5)

# %%
x_train_tips = x_train.drop(columns = ['sex','smoker','day','time']).values

# %%
x_test_tips = x_test.drop(columns = ['sex','smoker','day','time']).values

# %%
x_train_tips.shape
# Out:
# (195, 1)

# %%
transformed = np.concatenate((x_train_tips,x_train_sex,x_train_dt),axis = 1)

# %%
x_test_transformed = np.concatenate((x_test_tips,x_test_sex,x_test_dt), axis = 1)

# %%
transformed.shape
# Out:
# (195, 7)

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers = [
    ('a',OrdinalEncoder(categories = [['Female','Male']]),['sex']),
    ('b',OneHotEncoder(sparse_output = False , drop = 'first'),['time','day','smoker']),

],remainder = 'passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (195, 7)

# %%
transformer.fit_transform(x_test).shape
# Out:
# (49, 7)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/credit_scoring.csv")
df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22           2685.0                          2
# 1                      0.20           2371.0                          9
# 2                      0.22           2771.0                          6
# 3                      0.12           1371.0                          2
# 4                      0.99            828.0                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Marital Status               0
# Education Level              0
# Employment Status            0
# Credit Utilization Ratio     0
# Payment History              0
# Number of Credit Accounts    0
# Loan Amount                  0
# Interest Rate                0
# Loan Term                    0
# Type of Loan                 0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(df.drop(columns = 'Loan Amount'), df['Loan Amount'],test_size=0.2,random_state = 1)

# %%
x_train.shape
# Out:
# (800, 11)

# %%
x_test.shape
# Out:
# (200, 11)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df['Marital Status'].value_counts()
# Out:
# Marital Status
# Married     350
# Divorced    326
# Single      324
# Name: count, dtype: int64

# %%
oe = OrdinalEncoder(categories = [['Male','Female']])
x_train_gender=oe.fit_transform(x_train[['Gender']])

x_test_gender = oe.fit_transform(x_test[['Gender']])

x_train_gender.shape
# Out:
# (800, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse_output = False , drop = 'first')
x_train_mee = ohe.fit_transform(x_train[["Marital Status",'Education Level','Employment Status']])

# %%
x_test_mee = ohe.fit_transform(x_test[["Marital Status",'Education Level','Employment Status']])

# %%
x_train_mee.shape
# Out:
# (800, 7)

# %%
x_train['Type of Loan'].value_counts()
# Out:
# Type of Loan
# Auto Loan        279
# Personal Loan    261
# Home Loan        260
# Name: count, dtype: int64

# %%
oe = OrdinalEncoder(categories = [['Auto Loan','Personal Loan','Home Loan']])
x_train_loan = oe.fit_transform(x_train[["Type of Loan"]])

# %%
x_test_loan = oe.fit_transform(x_test[['Type of Loan']])

# %%
x_train_loan.shape
# Out:
# (800, 1)

# %%
x_train_numerical = x_train.select_dtypes(include = 'number').values

# %%
x_test_numerical = x_test.select_dtypes(include = 'number').values

# %%
x_train_transformed = np.concatenate((x_train_numerical,x_train_gender ,x_train_mee,x_train_loan ),axis = 1)

# %%
x_train_transformed.shape
# Out:
# (800, 15)

# %% [markdown]
# #column transformer

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('a',OrdinalEncoder(categories = [['Male','Female'],['Auto Loan','Personal Loan','Home Loan']]),['Gender','Type of Loan']),
    ('b',OneHotEncoder(sparse_output=False , drop= 'first'),["Marital Status",'Education Level','Employment Status'])
],remainder ='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (800, 15)

# %%
df1 = pd.read_csv("/content/insurance.csv")
df1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df1.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(df1.drop(columns = ['charges']), df1['charges'],test_size = 0.2,random_state = 1)

# %%
x_train.shape
# Out:
# (1070, 6)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories = [['female','male']])
x_train_sex = oe.fit_transform(x_train[['sex']])
x_test_sex = oe.fit_transform(x_test[['sex']])

# %%
x_train_sex.shape
# Out:
# (1070, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse_output = False , drop = 'first')
x_train_smoker_region = ohe.fit_transform(x_train[['smoker','region']])
x_test_smoker_region = ohe.fit_transform(x_test[['smoker','region']])

# %%
x_train_smoker_region.shape
# Out:
# (1070, 4)

# %%
x_num = x_train.select_dtypes(include='number').values

# %%
x_test_num = x_test.select_dtypes(include = 'number').values

# %%
x_train_transform = np.concatenate((x_num , x_train_sex , x_train_smoker_region),axis = 1)

# %%
x_test_transform = np.concatenate((x_test_num,x_test_sex,x_test_smoker_region),axis = 1)

# %%
x_train_transform.shape
# Out:
# (1070, 8)

# %% [markdown]
# #column transformer

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('a',OrdinalEncoder(categories=[['male','female']]),['sex']),
    ('b',OneHotEncoder(drop = 'first',sparse_output = False),('smoker','region'))
],remainder = 'passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (1070, 8)
